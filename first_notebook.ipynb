# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# “This is a verbal description”

# %% [markdown]
# <span style="color:darkblue"> Lecture 1: Introduction to Jupyter Notebooks </span>

# %% [markdown]
# <span style="color:green"> Lecture 1: Introduction to Jupyter Notebooks </span>

# %% [markdown]
# <span style="color:darkred"> Lecture 1: Introduction to Jupyter Notebooks </span>

# %% [markdown]
# <span style="color:white; font-size:28px;"> This is my first Jupyter Notebook </span>

# %% [markdown]
# <span style="color:white; font-size:8px;"> This is my first Jupyter Notebook </span>
